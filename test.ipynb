# %%
import pandas as pd

email_data = pd.read_csv('data/temp.csv')
email_data
# Out:
#      Unnamed: 0 account_name   account_mail_address                  receiver  \
# 0             0  Yicheng Zhu  yz1232@georgetown.edu     yz1232@georgetown.edu
# 1             1  Yicheng Zhu  yz1232@georgetown.edu  undisclosed-recipients:;
# 2             2  Yicheng Zhu  yz1232@georgetown.edu   <yz1232@georgetown.edu>
# 3             3  Yicheng Zhu  yz1232@georgetown.edu  undisclosed-recipients:;
# 4             4  Yicheng Zhu  yz1232@georgetown.edu     yz1232@georgetown.edu
# ..          ...          ...                    ...                       ...
# 101         101  Yicheng Zhu  yz1232@georgetown.edu     yz1232@georgetown.edu
# 102         102  Yicheng Zhu  yz1232@georgetown.edu  undisclosed-recipients:;
# 103         103  Yicheng Zhu  yz1232@georgetown.edu     yz1232@georgetown.edu
# 104         104  Yicheng Zhu  yz1232@georgetown.edu     yz1232@georgetown.edu
# 105         105  Yicheng Zhu  yz1232@georgetown.edu   <yz1232@georgetown.edu>
#
# ...

# %%
email_data['sender'].unique()
# Out:
# array(['55 H St. <55hst@georgetown.edu>',
#        'Purna Gamage <Purna.Gamage@georgetown.edu>',
#        'Office of the President <officeofthepresident@info.georgetown.edu>',
#        'Heather Connor <heather.connor@georgetown.edu>',
#        'Data Science and Analytics.Fall2023 <notifications@instructure.com>',
#        'GU Events <guevents@info.georgetown.edu>',
#        'GU Course Evaluations <noreply@eval.georgetown.edu>',
#        'Computational Ling Adv Python.Fall2023 <notifications@instructure.com>',
#        'Georgetown Canvas <notifications@instructure.com>',
#        'Grad Gazette <gradgazette@info.georgetown.edu>',
#        'Georgetown University RA Selection Committee <raselection@georgetown.edu>',
#        'Yicheng Zhu <yz1232@georgetown.edu>',
#        'James Hickman <jh2343@georgetown.edu>',
#        'Storage Scholars <hello@mail.storagescholars.com>',
#        'Ashley Stowe <ashley.stowe@georgetown.edu>',
# ...
